# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats =  np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs =  np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates =  list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f57dffac2413e19cf3aa05fd02a68e90

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_wdesc = city_weather["weather"][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_wdesc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | seoul
# Processing Record 2 of Set 1 | gamba
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | linqiong
# Processing Record 7 of Set 1 | yatou
# Processing Record 8 of Set 1 | pachino
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | coquimbo
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | saint-philippe
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | sao jose da coroa grande
# Processing Record 19 of Set 1 | cabo san lucas
# Processing Record 20 of Set 1 | hasaki
# Processing Record 21 of Set 1 | omboue
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | halifax
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 31 of Set 1 | aksu
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | rakitnoye
# Processing Record 34 of Set 1 | zastron
# Processing Record 35 of Set 1 | ribeira grande
# Processing Record 36 of Set 1 | mabini
# Processing Record 37 of Set 1 | pousat
# City not found. Skipping...
# Processing Record 38 of Set 1 | luba
# Processing Record 39 of Set 1 | lavrentiya
# Processing Record 40 of Set 1 | tiarei
# Processing Record 41 of Set 1 | lucapa
# Processing Record 42 of Set 1 | ahipara
# Processing Record 43 of Set 1 | caravelas
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | dingle
# Processing Record 46 of Set 1 | benguela
# Processing Record 47 of Set 1 | victoria
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | lugovskiy
# City not found. Skipping...
# Processing Record 1 of Set 2 | husavik
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | carlos antonio lopez
# Processing Record 4 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 2 | ukiah
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | charyshskoye
# Processing Record 8 of Set 2 | adrar
# Processing Record 9 of Set 2 | thompson
# Processing Record 10 of Set 2 | cervignano del friuli
# Processing Record 11 of Set 2 | cherskiy
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | labuhan
# Processing Record 14 of Set 2 | touros
# Processing Record 15 of Set 2 | isangel
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | vila velha
# Processing Record 19 of Set 2 | lata
# Processing Record 20 of Set 2 | dunmanway
# Processing Record 21 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | allende
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | richards bay
# Processing Record 27 of Set 2 | riyadh
# Processing Record 28 of Set 2 | chernyshevskiy
# Processing Record 29 of Set 2 | nishihara
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | sidi ali
# Processing Record 32 of Set 2 | kozhva
# Processing Record 33 of Set 2 | airai
# Processing Record 34 of Set 2 | nikolskoye
# Processing Record 35 of Set 2 | necochea
# Processing Record 36 of Set 2 | marzuq
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | yongan
# Processing Record 39 of Set 2 | ingham
# Processing Record 40 of Set 2 | homer
# Processing Record 41 of Set 2 | cap malheureux
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | tautira
# Processing Record 44 of Set 2 | esperance
# Processing Record 45 of Set 2 | saint-francois
# Processing Record 46 of Set 2 | san cristobal
# Processing Record 47 of Set 2 | biysk
# Processing Record 48 of Set 2 | aragarcas
# Processing Record 49 of Set 2 | hualmay
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | luderitz
# Processing Record 2 of Set 3 | ayan
# Processing Record 3 of Set 3 | nsukka
# Processing Record 4 of Set 3 | ponta do sol
# Processing Record 5 of Set 3 | traverse city
# Processing Record 6 of Set 3 | grajau
# Processing Record 7 of Set 3 | goderich
# Processing Record 8 of Set 3 | cascais
# Processing Record 9 of Set 3 | pisco
# Processing Record 10 of Set 3 | ancud
# Processing Record 11 of Set 3 | sakaiminato
# Processing Record 12 of Set 3 | qaanaaq
# Processing Record 13 of Set 3 | almeirim
# Processing Record 14 of Set 3 | mount isa
# Processing Record 15 of Set 3 | aliwal north
# Processing Record 16 of Set 3 | yellamanchili
# City not found. Skipping...
# Processing Record 17 of Set 3 | geraldton
# Processing Record 18 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 3 | jalu
# Processing Record 20 of Set 3 | guerrero negro
# Processing Record 21 of Set 3 | meulaboh
# Processing Record 22 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 3 | navlya
# Processing Record 24 of Set 3 | boyabat
# Processing Record 25 of Set 3 | stavern
# Processing Record 26 of Set 3 | aberdeen
# Processing Record 27 of Set 3 | cidreira
# Processing Record 28 of Set 3 | kozelsk
# Processing Record 29 of Set 3 | plouzane
# Processing Record 30 of Set 3 | dir
# Processing Record 31 of Set 3 | dudinka
# Processing Record 32 of Set 3 | atuona
# Processing Record 33 of Set 3 | tura
# Processing Record 34 of Set 3 | kodinsk
# Processing Record 35 of Set 3 | dukat
# Processing Record 36 of Set 3 | mahebourg
# Processing Record 37 of Set 3 | carnarvon
# Processing Record 38 of Set 3 | ahuimanu
# Processing Record 39 of Set 3 | bengkulu
# Processing Record 40 of Set 3 | vanimo
# Processing Record 41 of Set 3 | barrow
# Processing Record 42 of Set 3 | shimoda
# Processing Record 43 of Set 3 | saint-denis
# Processing Record 44 of Set 3 | tiksi
# Processing Record 45 of Set 3 | katsuura
# Processing Record 46 of Set 3 | griffith
# Processing Record 47 of Set 3 | acari
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | half moon bay
# Processing Record 50 of Set 3 | kodiak
# Processing Record 1 of Set 4 | saint anthony
# Processing Record 2 of Set 4 | arraial do cabo
# Processing Record 3 of Set 4 | xiaoweizhai
# Processing Record 4 of Set 4 | north myrtle beach
# Processing Record 5 of Set 4 | nanakuli
# Processing Record 6 of Set 4 | bethel
# Processing Record 7 of Set 4 | praia
# Processing Record 8 of Set 4 | ranau
# Processing Record 9 of Set 4 | warangal
# Processing Record 10 of Set 4 | mocuba
# Processing Record 11 of Set 4 | romanovskaya
# Processing Record 12 of Set 4 | bluff
# Processing Record 13 of Set 4 | balkanabat
# Processing Record 14 of Set 4 | konevo
# Processing Record 15 of Set 4 | mackenzie
# Processing Record 16 of Set 4 | faanui
# Processing Record 17 of Set 4 | mackay
# Processing Record 18 of Set 4 | kavieng
# Processing Record 19 of Set 4 | fukue
# Processing Record 20 of Set 4 | dunedin
# Processing Record 21 of Set 4 | preobrazheniye
# Processing Record 22 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 4 | bambous virieux
# Processing Record 26 of Set 4 | mount gambier
# Processing Record 27 of Set 4 | bathsheba
# Processing Record 28 of Set 4 | alice springs
# Processing Record 29 of Set 4 | georgetown
# Processing Record 30 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 4 | shimanovsk
# Processing Record 33 of Set 4 | haines junction
# Processing Record 34 of Set 4 | chapais
# Processing Record 35 of Set 4 | honningsvag
# Processing Record 36 of Set 4 | kudahuvadhoo
# Processing Record 37 of Set 4 | port hardy
# Processing Record 38 of Set 4 | stornoway
# Processing Record 39 of Set 4 | qasigiannguit
# Processing Record 40 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 4 | butaritari
# Processing Record 42 of Set 4 | cape town
# Processing Record 43 of Set 4 | tigil
# Processing Record 44 of Set 4 | hithadhoo
# Processing Record 45 of Set 4 | bouar
# Processing Record 46 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 4 | lompoc
# Processing Record 48 of Set 4 | portland
# Processing Record 49 of Set 4 | bastia
# Processing Record 50 of Set 4 | leningradskiy
# Processing Record 1 of Set 5 | kibala
# Processing Record 2 of Set 5 | lufilufi
# Processing Record 3 of Set 5 | mumford
# Processing Record 4 of Set 5 | gudur
# Processing Record 5 of Set 5 | albany
# Processing Record 6 of Set 5 | rosia montana
# City not found. Skipping...
# Processing Record 7 of Set 5 | santa rita
# Processing Record 8 of Set 5 | avera
# Processing Record 9 of Set 5 | ketchikan
# Processing Record 10 of Set 5 | carahue
# Processing Record 11 of Set 5 | batagay
# Processing Record 12 of Set 5 | chara
# Processing Record 13 of Set 5 | rock sound
# Processing Record 14 of Set 5 | ust-tsilma
# Processing Record 15 of Set 5 | yar-sale
# Processing Record 16 of Set 5 | denpasar
# Processing Record 17 of Set 5 | pilao arcado
# City not found. Skipping...
# Processing Record 18 of Set 5 | troy
# Processing Record 19 of Set 5 | huarmey
# Processing Record 20 of Set 5 | ust-kut
# Processing Record 21 of Set 5 | ixtapa
# Processing Record 22 of Set 5 | bilibino
# Processing Record 23 of Set 5 | kovdor
# Processing Record 24 of Set 5 | paragominas
# Processing Record 25 of Set 5 | hambantota
# Processing Record 26 of Set 5 | ashta
# Processing Record 27 of Set 5 | biltine
# Processing Record 28 of Set 5 | camacha
# Processing Record 29 of Set 5 | saldanha
# Processing Record 30 of Set 5 | sambava
# Processing Record 31 of Set 5 | lithgow
# Processing Record 32 of Set 5 | sao felix do xingu
# Processing Record 33 of Set 5 | alashtar
# City not found. Skipping...
# Processing Record 34 of Set 5 | seymchan
# Processing Record 35 of Set 5 | makakilo city
# Processing Record 36 of Set 5 | chumikan
# Processing Record 37 of Set 5 | coahuayana
# Processing Record 38 of Set 5 | gilbues
# Processing Record 39 of Set 5 | praia da vitoria
# Processing Record 40 of Set 5 | upernavik
# Processing Record 41 of Set 5 | suntar
# Processing Record 42 of Set 5 | bireun
# Processing Record 43 of Set 5 | boralday
# Processing Record 44 of Set 5 | rosarito
# Processing Record 45 of Set 5 | haapsalu
# Processing Record 46 of Set 5 | kasongo-lunda
# Processing Record 47 of Set 5 | puri
# Processing Record 48 of Set 5 | aklavik
# Processing Record 49 of Set 5 | doha
# Processing Record 50 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 6 | oussouye
# Processing Record 2 of Set 6 | huilong
# Processing Record 3 of Set 6 | jiayuguan
# Processing Record 4 of Set 6 | nuuk
# Processing Record 5 of Set 6 | vitim
# Processing Record 6 of Set 6 | laramie
# Processing Record 7 of Set 6 | karratha
# Processing Record 8 of Set 6 | illela
# Processing Record 9 of Set 6 | seminole
# Processing Record 10 of Set 6 | muzhi
# Processing Record 11 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 6 | povolzhskiy
# Processing Record 13 of Set 6 | magnor
# Processing Record 14 of Set 6 | monrovia
# Processing Record 15 of Set 6 | rudnya
# Processing Record 16 of Set 6 | villa carlos paz
# Processing Record 17 of Set 6 | leua
# Processing Record 18 of Set 6 | hamilton
# Processing Record 19 of Set 6 | sadovoye
# Processing Record 20 of Set 6 | zavetnoye
# Processing Record 21 of Set 6 | kahului
# Processing Record 22 of Set 6 | westport
# Processing Record 23 of Set 6 | ugoofaaru
# Processing Record 24 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 6 | sioux lookout
# Processing Record 26 of Set 6 | batticaloa
# Processing Record 27 of Set 6 | gizo
# Processing Record 28 of Set 6 | calamar
# Processing Record 29 of Set 6 | asau
# Processing Record 30 of Set 6 | hofn
# Processing Record 31 of Set 6 | phek
# Processing Record 32 of Set 6 | ninghai
# Processing Record 33 of Set 6 | olinda
# Processing Record 34 of Set 6 | kyra
# Processing Record 35 of Set 6 | svetlogorsk
# Processing Record 36 of Set 6 | yeppoon
# Processing Record 37 of Set 6 | karasjok
# Processing Record 38 of Set 6 | miles city
# Processing Record 39 of Set 6 | lima
# Processing Record 40 of Set 6 | manacapuru
# Processing Record 41 of Set 6 | loucovice
# Processing Record 42 of Set 6 | kirakira
# Processing Record 43 of Set 6 | te anau
# Processing Record 44 of Set 6 | oranjemund
# Processing Record 45 of Set 6 | port moresby
# Processing Record 46 of Set 6 | novyye burasy
# Processing Record 47 of Set 6 | tefe
# Processing Record 48 of Set 6 | urumqi
# Processing Record 49 of Set 6 | havoysund
# Processing Record 50 of Set 6 | mnogovershinnyy
# Processing Record 1 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 2 of Set 7 | eydhafushi
# Processing Record 3 of Set 7 | pevek
# Processing Record 4 of Set 7 | alofi
# Processing Record 5 of Set 7 | acajutla
# Processing Record 6 of Set 7 | tromso
# Processing Record 7 of Set 7 | flin flon
# Processing Record 8 of Set 7 | uchana
# Processing Record 9 of Set 7 | inirida
# Processing Record 10 of Set 7 | santo antonio do ica
# Processing Record 11 of Set 7 | eyl
# Processing Record 12 of Set 7 | ongandjera
# Processing Record 13 of Set 7 | southbridge
# Processing Record 14 of Set 7 | hami
# Processing Record 15 of Set 7 | kindu
# Processing Record 16 of Set 7 | bosaso
# Processing Record 17 of Set 7 | padang
# Processing Record 18 of Set 7 | uzunovo
# Processing Record 19 of Set 7 | ulety
# Processing Record 20 of Set 7 | lewisporte
# Processing Record 21 of Set 7 | buenos aires
# Processing Record 22 of Set 7 | muroto
# Processing Record 23 of Set 7 | codrington
# Processing Record 24 of Set 7 | poronaysk
# Processing Record 25 of Set 7 | sao joao da barra
# Processing Record 26 of Set 7 | tamworth
# Processing Record 27 of Set 7 | trelew
# Processing Record 28 of Set 7 | udachnyy
# Processing Record 29 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 7 | inuvik
# Processing Record 31 of Set 7 | havre-saint-pierre
# Processing Record 32 of Set 7 | vardo
# Processing Record 33 of Set 7 | agadez
# Processing Record 34 of Set 7 | yurgamysh
# Processing Record 35 of Set 7 | panyutyne
# Processing Record 36 of Set 7 | bafang
# Processing Record 37 of Set 7 | amurzet
# Processing Record 38 of Set 7 | palmer
# Processing Record 39 of Set 7 | san-pedro
# Processing Record 40 of Set 7 | lethem
# Processing Record 41 of Set 7 | mareeba
# Processing Record 42 of Set 7 | peace river
# Processing Record 43 of Set 7 | bilma
# Processing Record 44 of Set 7 | krasnoselkup
# Processing Record 45 of Set 7 | rio branco
# Processing Record 46 of Set 7 | misratah
# Processing Record 47 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 7 | norman wells
# Processing Record 50 of Set 7 | ayagoz
# Processing Record 1 of Set 8 | lagoa
# Processing Record 2 of Set 8 | kaitangata
# Processing Record 3 of Set 8 | merauke
# Processing Record 4 of Set 8 | beisfjord
# Processing Record 5 of Set 8 | narsaq
# Processing Record 6 of Set 8 | pochutla
# Processing Record 7 of Set 8 | oskemen
# Processing Record 8 of Set 8 | maun
# Processing Record 9 of Set 8 | linchuan
# City not found. Skipping...
# Processing Record 10 of Set 8 | torbay
# Processing Record 11 of Set 8 | milkovo
# Processing Record 12 of Set 8 | bayir
# Processing Record 13 of Set 8 | mangan
# Processing Record 14 of Set 8 | lebedinyy
# Processing Record 15 of Set 8 | tessalit
# Processing Record 16 of Set 8 | pendleton
# Processing Record 17 of Set 8 | yerbogachen
# Processing Record 18 of Set 8 | shingu
# Processing Record 19 of Set 8 | san andres
# Processing Record 20 of Set 8 | suez
# Processing Record 21 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 22 of Set 8 | redwater
# Processing Record 23 of Set 8 | severo-kurilsk
# Processing Record 24 of Set 8 | tuatapere
# Processing Record 25 of Set 8 | quatre cocos
# Processing Record 26 of Set 8 | roma
# Processing Record 27 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 28 of Set 8 | thinadhoo
# Processing Record 29 of Set 8 | sitka
# Processing Record 30 of Set 8 | altamont
# Processing Record 31 of Set 8 | burica
# City not found. Skipping...
# Processing Record 32 of Set 8 | faya
# Processing Record 33 of Set 8 | aripuana
# Processing Record 34 of Set 8 | kalmunai
# Processing Record 35 of Set 8 | winneba
# Processing Record 36 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 8 | pangnirtung
# Processing Record 38 of Set 8 | boone
# Processing Record 39 of Set 8 | lushunkou
# City not found. Skipping...
# Processing Record 40 of Set 8 | sungaipenuh
# Processing Record 41 of Set 8 | white rock
# Processing Record 42 of Set 8 | berlevag
# Processing Record 43 of Set 8 | barcelos
# Processing Record 44 of Set 8 | garissa
# Processing Record 45 of Set 8 | mitsamiouli
# Processing Record 46 of Set 8 | petatlan
# Processing Record 47 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 8 | yang talat
# Processing Record 49 of Set 8 | kupang
# Processing Record 50 of Set 8 | tarabha
# Processing Record 1 of Set 9 | lokoja
# Processing Record 2 of Set 9 | batagay-alyta
# Processing Record 3 of Set 9 | tazovskiy
# Processing Record 4 of Set 9 | port macquarie
# Processing Record 5 of Set 9 | vila do maio
# Processing Record 6 of Set 9 | abu samrah
# Processing Record 7 of Set 9 | bahia blanca
# Processing Record 8 of Set 9 | ahualulco
# Processing Record 9 of Set 9 | kieta
# Processing Record 10 of Set 9 | khani
# Processing Record 11 of Set 9 | araouane
# Processing Record 12 of Set 9 | naryan-mar
# Processing Record 13 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 9 | beloit
# Processing Record 15 of Set 9 | grindavik
# Processing Record 16 of Set 9 | urengoy
# Processing Record 17 of Set 9 | inhambane
# Processing Record 18 of Set 9 | harlingen
# Processing Record 19 of Set 9 | dakar
# Processing Record 20 of Set 9 | klaksvik
# Processing Record 21 of Set 9 | loknya
# Processing Record 22 of Set 9 | naliya
# Processing Record 23 of Set 9 | yulara
# Processing Record 24 of Set 9 | agara
# Processing Record 25 of Set 9 | ballina
# Processing Record 26 of Set 9 | nome
# Processing Record 27 of Set 9 | nanortalik
# Processing Record 28 of Set 9 | waipawa
# Processing Record 29 of Set 9 | akhalgori
# Processing Record 30 of Set 9 | priyutnoye
# Processing Record 31 of Set 9 | mlalo
# Processing Record 32 of Set 9 | iskateley
# Processing Record 33 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 9 | raymond terrace
# Processing Record 35 of Set 9 | aquiraz
# Processing Record 36 of Set 9 | vyshhorod
# Processing Record 37 of Set 9 | jaisalmer
# Processing Record 38 of Set 9 | ferrol
# Processing Record 39 of Set 9 | sug-aksy
# City not found. Skipping...
# Processing Record 40 of Set 9 | taber
# Processing Record 41 of Set 9 | aykhal
# Processing Record 42 of Set 9 | dwarka
# Processing Record 43 of Set 9 | vila franca do campo
# Processing Record 44 of Set 9 | niceville
# Processing Record 45 of Set 9 | berdigestyakh
# Processing Record 46 of Set 9 | san juan
# Processing Record 47 of Set 9 | roura
# Processing Record 48 of Set 9 | muravlenko
# Processing Record 49 of Set 9 | caninde
# Processing Record 50 of Set 9 | tabuk
# Processing Record 1 of Set 10 | pilar
# Processing Record 2 of Set 10 | prosvet
# Processing Record 3 of Set 10 | sao filipe
# Processing Record 4 of Set 10 | parrita
# Processing Record 5 of Set 10 | mistelbach
# Processing Record 6 of Set 10 | ostrovnoy
# Processing Record 7 of Set 10 | blagodatnoye
# Processing Record 8 of Set 10 | chunskiy
# Processing Record 9 of Set 10 | palmerston
# Processing Record 10 of Set 10 | carutapera
# Processing Record 11 of Set 10 | bahia honda
# Processing Record 12 of Set 10 | oga
# Processing Record 13 of Set 10 | tuy hoa
# Processing Record 14 of Set 10 | sorong
# Processing Record 15 of Set 10 | xining
# Processing Record 16 of Set 10 | mahibadhoo
# Processing Record 17 of Set 10 | paamiut
# Processing Record 18 of Set 10 | la reforma
# Processing Record 19 of Set 10 | iqaluit
# Processing Record 20 of Set 10 | fortuna
# Processing Record 21 of Set 10 | taltal
# Processing Record 22 of Set 10 | pizarro
# Processing Record 23 of Set 10 | marawi
# Processing Record 24 of Set 10 | wanaka
# Processing Record 25 of Set 10 | abatskoye
# Processing Record 26 of Set 10 | chokwe
# Processing Record 27 of Set 10 | mar del plata
# Processing Record 28 of Set 10 | broome
# Processing Record 29 of Set 10 | antofagasta
# Processing Record 30 of Set 10 | saint-louis
# Processing Record 31 of Set 10 | tucuman
# Processing Record 32 of Set 10 | cabreuva
# Processing Record 33 of Set 10 | gambela
# Processing Record 34 of Set 10 | osypenko
# Processing Record 35 of Set 10 | makat
# Processing Record 36 of Set 10 | komsomolskiy
# Processing Record 37 of Set 10 | iquitos
# Processing Record 38 of Set 10 | muros
# Processing Record 39 of Set 10 | erzin
# Processing Record 40 of Set 10 | reconquista
# Processing Record 41 of Set 10 | gazli
# Processing Record 42 of Set 10 | port blair
# Processing Record 43 of Set 10 | beidao
# Processing Record 44 of Set 10 | ormara
# Processing Record 45 of Set 10 | marrakesh
# Processing Record 46 of Set 10 | tarija
# Processing Record 47 of Set 10 | ocos
# Processing Record 48 of Set 10 | sangar
# Processing Record 49 of Set 10 | leh
# Processing Record 50 of Set 10 | souillac
# Processing Record 1 of Set 11 | gallup
# Processing Record 2 of Set 11 | sidney
# Processing Record 3 of Set 11 | salalah
# Processing Record 4 of Set 11 | cururupu
# Processing Record 5 of Set 11 | constitucion
# Processing Record 6 of Set 11 | fomboni
# Processing Record 7 of Set 11 | noshiro
# Processing Record 8 of Set 11 | teguldet
# Processing Record 9 of Set 11 | saskylakh
# Processing Record 10 of Set 11 | great yarmouth
# Processing Record 11 of Set 11 | kasama
# Processing Record 12 of Set 11 | buon me thuot
# City not found. Skipping...
# Processing Record 13 of Set 11 | poya
# Processing Record 14 of Set 11 | phu ly
# Processing Record 15 of Set 11 | ilulissat
# Processing Record 16 of Set 11 | comodoro rivadavia
# Processing Record 17 of Set 11 | baker city
# Processing Record 18 of Set 11 | san jose del palmar
# Processing Record 19 of Set 11 | awjilah
# Processing Record 20 of Set 11 | kodinar
# Processing Record 21 of Set 11 | stejaru
# Processing Record 22 of Set 11 | seddon
# Processing Record 23 of Set 11 | laguna
# Processing Record 24 of Set 11 | huaura
# Processing Record 25 of Set 11 | kumluca
# Processing Record 26 of Set 11 | eureka
# Processing Record 27 of Set 11 | ilhabela
# Processing Record 28 of Set 11 | pasni
# Processing Record 29 of Set 11 | ribas do rio pardo
# Processing Record 30 of Set 11 | coari
# Processing Record 31 of Set 11 | beloha
# Processing Record 32 of Set 11 | sao bento
# Processing Record 33 of Set 11 | banda aceh
# Processing Record 34 of Set 11 | lewiston
# Processing Record 35 of Set 11 | ponta delgada
# Processing Record 36 of Set 11 | acapulco
# Processing Record 37 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 11 | yenagoa
# Processing Record 39 of Set 11 | duvan
# Processing Record 40 of Set 11 | chulman
# Processing Record 41 of Set 11 | west des moines
# Processing Record 42 of Set 11 | rawson
# Processing Record 43 of Set 11 | ulladulla
# Processing Record 44 of Set 11 | olga
# Processing Record 45 of Set 11 | cabedelo
# Processing Record 46 of Set 11 | bahar
# Processing Record 47 of Set 11 | mendota
# Processing Record 48 of Set 11 | ushtobe
# Processing Record 49 of Set 11 | angoche
# Processing Record 50 of Set 11 | kurilsk
# Processing Record 1 of Set 12 | loralai
# Processing Record 2 of Set 12 | omsukchan
# Processing Record 3 of Set 12 | sola
# Processing Record 4 of Set 12 | kuusamo
# Processing Record 5 of Set 12 | lasa
# Processing Record 6 of Set 12 | oudtshoorn
# Processing Record 7 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 8 of Set 12 | northam
# Processing Record 9 of Set 12 | bar harbor
# Processing Record 10 of Set 12 | kulhudhuffushi
# Processing Record 11 of Set 12 | palpa
# Processing Record 12 of Set 12 | la cruz
# Processing Record 13 of Set 12 | gao
# Processing Record 14 of Set 12 | srivardhan
# Processing Record 15 of Set 12 | aviles
# Processing Record 16 of Set 12 | mogadishu
# Processing Record 17 of Set 12 | mudgee
# Processing Record 18 of Set 12 | yumen
# Processing Record 19 of Set 12 | panama city
# Processing Record 20 of Set 12 | broken hill
# Processing Record 21 of Set 12 | ariquemes
# Processing Record 22 of Set 12 | bardiyah
# Processing Record 23 of Set 12 | mehamn
# Processing Record 24 of Set 12 | beaupre
# Processing Record 25 of Set 12 | nipawin
# Processing Record 26 of Set 12 | daboh
# Processing Record 27 of Set 12 | popondetta
# Processing Record 28 of Set 12 | albox
# Processing Record 29 of Set 12 | khandbari
# Processing Record 30 of Set 12 | gawler
# Processing Record 31 of Set 12 | boke
# Processing Record 32 of Set 12 | poum
# Processing Record 33 of Set 12 | tiznit
# Processing Record 34 of Set 12 | kuytun
# Processing Record 35 of Set 12 | bambanglipuro
# Processing Record 36 of Set 12 | saint-joseph
# Processing Record 37 of Set 12 | ilo
# Processing Record 38 of Set 12 | taungdwingyi
# Processing Record 39 of Set 12 | vestmanna
# Processing Record 40 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 12 | tilichiki
# Processing Record 42 of Set 12 | tinskoy
# Processing Record 43 of Set 12 | escarcega
# Processing Record 44 of Set 12 | soe
# Processing Record 45 of Set 12 | hibbing
# Processing Record 46 of Set 12 | margate
# Processing Record 47 of Set 12 | chepareria
# Processing Record 48 of Set 12 | neuquen
# Processing Record 49 of Set 12 | gushikawa
# Processing Record 50 of Set 12 | liverpool
# Processing Record 1 of Set 13 | saint pete beach
# Processing Record 2 of Set 13 | lorengau
# Processing Record 3 of Set 13 | weymouth
# Processing Record 4 of Set 13 | san quintin
# Processing Record 5 of Set 13 | trincomalee
# Processing Record 6 of Set 13 | rundu
# Processing Record 7 of Set 13 | fort nelson
# Processing Record 8 of Set 13 | lazaro cardenas
# Processing Record 9 of Set 13 | damphu
# Processing Record 10 of Set 13 | dandong
# Processing Record 11 of Set 13 | sozimskiy
# Processing Record 12 of Set 13 | vestbygda
# City not found. Skipping...
# Processing Record 13 of Set 13 | amahai
# Processing Record 14 of Set 13 | hendijan
# City not found. Skipping...
# Processing Record 15 of Set 13 | tra vinh
# Processing Record 16 of Set 13 | cayenne
# Processing Record 17 of Set 13 | bemidji
# Processing Record 18 of Set 13 | high wycombe
# Processing Record 19 of Set 13 | lodwar
# Processing Record 20 of Set 13 | vegueta
# Processing Record 21 of Set 13 | vestmannaeyjar
# Processing Record 22 of Set 13 | port angeles
# Processing Record 23 of Set 13 | khuzdar
# Processing Record 24 of Set 13 | kosa
# Processing Record 25 of Set 13 | lagos
# Processing Record 26 of Set 13 | taoudenni
# Processing Record 27 of Set 13 | eirunepe
# Processing Record 28 of Set 13 | ulaanbaatar
# Processing Record 29 of Set 13 | port hedland
# Processing Record 30 of Set 13 | santiago del estero
# Processing Record 31 of Set 13 | baft
# Processing Record 32 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 33 of Set 13 | ribeira brava
# Processing Record 34 of Set 13 | choya
# Processing Record 35 of Set 13 | ville-marie
# Processing Record 36 of Set 13 | namatanai
# Processing Record 37 of Set 13 | porto-vecchio
# Processing Record 38 of Set 13 | montepuez
# Processing Record 39 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 40 of Set 13 | mattru
# Processing Record 41 of Set 13 | peruibe
# Processing Record 42 of Set 13 | inongo
# Processing Record 43 of Set 13 | ypsonas
# Processing Record 44 of Set 13 | tari
# Processing Record 45 of Set 13 | bara
# Processing Record 46 of Set 13 | talant
# Processing Record 47 of Set 13 | montrose
# Processing Record 48 of Set 13 | santos dumont
# Processing Record 49 of Set 13 | paka
# Processing Record 50 of Set 13 | mehran
# Processing Record 1 of Set 14 | emba
# Processing Record 2 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 14 | buala
# Processing Record 4 of Set 14 | dabakala
# Processing Record 5 of Set 14 | san isidro
# Processing Record 6 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 14 | fairbanks
# Processing Record 8 of Set 14 | canelones
# Processing Record 9 of Set 14 | kommunar
# Processing Record 10 of Set 14 | verkhnyaya toyma
# Processing Record 11 of Set 14 | wuda
# Processing Record 12 of Set 14 | maragogi
# Processing Record 13 of Set 14 | plettenberg bay
# Processing Record 14 of Set 14 | jacareacanga
# Processing Record 15 of Set 14 | colares
# Processing Record 16 of Set 14 | verkhnyaya inta
# Processing Record 17 of Set 14 | ternate
# Processing Record 18 of Set 14 | kochinda
# Processing Record 19 of Set 14 | olot
# Processing Record 20 of Set 14 | naze
# Processing Record 21 of Set 14 | chalus
# Processing Record 22 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 23 of Set 14 | gobabis
# Processing Record 24 of Set 14 | aitape
# Processing Record 25 of Set 14 | deputatskiy
# Processing Record 26 of Set 14 | skjervoy
# Processing Record 27 of Set 14 | khilok
# Processing Record 28 of Set 14 | nizwa
# Processing Record 29 of Set 14 | luanda
# Processing Record 30 of Set 14 | nizhniy tsasuchey
# Processing Record 31 of Set 14 | barinas
# Processing Record 32 of Set 14 | saravena
# Processing Record 33 of Set 14 | oistins
# Processing Record 34 of Set 14 | mayor pablo lagerenza
# Processing Record 35 of Set 14 | minggang
# Processing Record 36 of Set 14 | malazgirt
# Processing Record 37 of Set 14 | beringovskiy
# Processing Record 38 of Set 14 | aleksandrov gay
# Processing Record 39 of Set 14 | pacific grove
# Processing Record 40 of Set 14 | coxim
# Processing Record 41 of Set 14 | moba
# Processing Record 42 of Set 14 | kailua
# Processing Record 43 of Set 14 | baoshan
# Processing Record 44 of Set 14 | emerald
# Processing Record 45 of Set 14 | guntakal
# Processing Record 46 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 14 | manbij
# Processing Record 48 of Set 14 | sur
# Processing Record 49 of Set 14 | fernley
# Processing Record 50 of Set 14 | trairi
# Processing Record 1 of Set 15 | porto belo
# Processing Record 2 of Set 15 | ginir
# Processing Record 3 of Set 15 | rocha
# Processing Record 4 of Set 15 | raton
# Processing Record 5 of Set 15 | kortkeros
# Processing Record 6 of Set 15 | chengdu
# Processing Record 7 of Set 15 | boyolangu
# Processing Record 8 of Set 15 | kavaratti
# Processing Record 9 of Set 15 | clyde river
# Processing Record 10 of Set 15 | egvekinot
# Processing Record 11 of Set 15 | parati
# Processing Record 12 of Set 15 | heidenreichstein
# Processing Record 13 of Set 15 | calabozo
# Processing Record 14 of Set 15 | matamoros
# Processing Record 15 of Set 15 | ji-parana
# City not found. Skipping...
# Processing Record 16 of Set 15 | loandjili
# Processing Record 17 of Set 15 | kongsberg
# Processing Record 18 of Set 15 | lovozero
# Processing Record 19 of Set 15 | college
# Processing Record 20 of Set 15 | oksfjord
# Processing Record 21 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 22 of Set 15 | saint-pierre
# Processing Record 23 of Set 15 | masaguisi
# Processing Record 24 of Set 15 | champerico
# Processing Record 25 of Set 15 | haag
# Processing Record 26 of Set 15 | singkawang
# Processing Record 27 of Set 15 | barma
# Processing Record 28 of Set 15 | baicheng
# Processing Record 29 of Set 15 | conceicao da barra
# Processing Record 30 of Set 15 | jimma
# Processing Record 31 of Set 15 | mount kisco
# Processing Record 32 of Set 15 | novyy urengoy
# Processing Record 33 of Set 15 | gat
# Processing Record 34 of Set 15 | zanjan
# Processing Record 35 of Set 15 | salcininkai
# Processing Record 36 of Set 15 | myrtle beach
# Processing Record 37 of Set 15 | gela
# Processing Record 38 of Set 15 | saint-augustin
# Processing Record 39 of Set 15 | pozo colorado
# Processing Record 40 of Set 15 | weligama
# Processing Record 41 of Set 15 | kpalime
# Processing Record 42 of Set 15 | dalvik
# Processing Record 43 of Set 15 | marystown
# Processing Record 44 of Set 15 | nouakchott
# Processing Record 45 of Set 15 | padilla
# Processing Record 46 of Set 15 | takoradi
# Processing Record 47 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 15 | hobyo
# Processing Record 49 of Set 15 | san carlos de bariloche
# Processing Record 50 of Set 15 | aksarka
# Processing Record 1 of Set 16 | srednekolymsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 699

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Seoul  37.5683  126.9778     67.44        94          75
# 1         Gamba  -2.6500   10.0000     75.47        86          93
# 2  Longyearbyen  78.2186   15.6401     31.84        86           0
# 3  Kruisfontein -34.0033   24.7314     58.89        97         100
# 4      Linqiong  30.4159  103.4609     74.57        81          95
# 5         Yatou  37.1500  122.3833     70.16        89          18
# 6       Pachino  36.7186   15.0907     73.44        73           3
# 7      Hermanus -34.4187   19.2345     60.91        81          77
# 8      Coquimbo -29.9533  -71.3436     57.38        74           0
# 9   Port Alfred -33.5906   26.8910     61.99        92          15
#
#    Wind Speed Country Current Description
# 0        6.91      KR                mist
# 1        7.72      GA     overcast clouds
# 2        2.30      SJ           clear sky
# 3        2.53      ZA          light rain
# 4        1.03      CN     overcast clouds
# 5        5.23      CN          few clouds
# 6        9.66      IT           clear sky
# 7        9.08      ZA       broken clouds
# 8        7.96      CL           clear sky
# 9        4.68      ZA          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Seoul      KR  37.5683  126.9778     67.44        94          75
# 1         Gamba      GA  -2.6500   10.0000     75.47        86          93
# 2  Longyearbyen      SJ  78.2186   15.6401     31.84        86           0
# 3  Kruisfontein      ZA -34.0033   24.7314     58.89        97         100
# 4      Linqiong      CN  30.4159  103.4609     74.57        81          95
# 5         Yatou      CN  37.1500  122.3833     70.16        89          18
# 6       Pachino      IT  36.7186   15.0907     73.44        73           3
# 7      Hermanus      ZA -34.4187   19.2345     60.91        81          77
# 8      Coquimbo      CL -29.9533  -71.3436     57.38        74           0
# 9   Port Alfred      ZA -33.5906   26.8910     61.99        92          15
#
#    Wind Speed Current Description
# 0        6.91                mist
# 1        7.72     overcast clouds
# 2        2.30           clear sky
# 3        2.53          light rain
# 4        1.03     overcast clouds
# 5        5.23          few clouds
# 6        9.66           clear sky
# 7        9.08       broken clouds
# 8        7.96           clear sky
# 9        4.68          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
